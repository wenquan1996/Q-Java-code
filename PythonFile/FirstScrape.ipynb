# %%
import json
import oauth2 as oauth
import twitter
import numpy as np
import pandas as pd
import tweepy

# %%
consumer_key = 'nRO8b2R7tnipKtrFTJVRUru7V'  
consumer_secret = 'bK2v3PVVZGktAT2BbviC96Tz9vzjq0ZDj2WLKZ1pmm5aGgu4eW'  
access_token = '1098973181468205057-xXfZG8xbtYbXjE6T2s0Ok5J0bKRpsN'  
access_token_secret = 'W7muOM4ABrbSH59nHLH43YMeRl3GZCfN1v8FOh1p8tPHh' 
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)  
auth.set_access_token(access_token, access_token_secret)  
  
api = tweepy.API(auth)

# %%
df.to_csv('NBA_Twitter_Acount.CSV')

# %%
tweets = api.user_timeline('warriors',count=100)
jt = api.get_user('warriors')
for tweet in tweets:
    df = pd.DataFrame(data=[tweet.user.screen_name for tweet in tweets], columns=['Name'])
    df['id'] = np.array([jt.id for tweet in tweets])
    df['likes'] = np.array([tweet.favorite_count for tweet in tweets])
    df['date']=np.array([tweet.created_at for tweet in tweets])
    df['posts']= np.array([tweet.text for tweet in tweets])
    df["retweets"] = np.array([tweet.retweet_count for tweet in tweets])
    
df
# Out:
#         Name        id  likes                date  \
# 0   warriors  26270913    259 2019-03-06 03:43:20
# 1   warriors  26270913    299 2019-03-06 03:40:50
# 2   warriors  26270913   1315 2019-03-06 03:28:10
# 3   warriors  26270913    442 2019-03-06 03:21:50
# 4   warriors  26270913   1534 2019-03-06 03:16:42
# 5   warriors  26270913    604 2019-03-06 03:15:24
# 6   warriors  26270913    536 2019-03-06 02:30:00
# 7   warriors  26270913   1749 2019-03-06 02:11:21
# 8   warriors  26270913      0 2019-03-05 21:59:02
# 9   warriors  26270913   1948 2019-03-05 21:12:00
# 10  warriors  26270913   2665 2019-03-05 19:21:20
# 11  warriors  26270913   2215 2019-03-05 19:16:02
# 12  warriors  26270913    479 2019-03-05 18:41:24
# 13  warriors  26270913   1987 2019-03-05 17:44:00
# 14  warriors  26270913   1202 2019-03-05 16:43:00
# 15  warriors  26270913   1296 2019-03-05 00:45:00
# 16  warriors  26270913    472 2019-03-04 23:33:01
# 17  warriors  26270913   3947 2019-03-04 21:30:12
# ...

# %%
df.to_csv('Warriors_Twitter_Account.csv')

# %%
tweets = api.user_timeline('HoustonRockets',count=100)
jt = api.get_user('HoustonRockets')
for tweet in tweets:
    df = pd.DataFrame(data=[tweet.user.screen_name for tweet in tweets], columns=['Name'])
    df['id'] = np.array([jt.id for tweet in tweets])
    df['likes'] = np.array([tweet.favorite_count for tweet in tweets])
    df['date']=np.array([tweet.created_at for tweet in tweets])
    df['posts']= np.array([tweet.text for tweet in tweets])
    df["retweets"] = np.array([tweet.retweet_count for tweet in tweets])
    
df
# Out:
#               Name        id  likes                date  \
# 0   HoustonRockets  19077044    956 2019-03-06 03:29:38
# 1   HoustonRockets  19077044   1012 2019-03-06 03:29:11
# 2   HoustonRockets  19077044    446 2019-03-06 03:25:35
# 3   HoustonRockets  19077044    386 2019-03-06 03:15:25
# 4   HoustonRockets  19077044    196 2019-03-06 03:11:30
# 5   HoustonRockets  19077044    179 2019-03-06 03:06:44
# 6   HoustonRockets  19077044    163 2019-03-06 03:06:08
# 7   HoustonRockets  19077044     62 2019-03-06 03:05:43
id'] = np.array([tweet.id for tweet in tweepy.Cursor(api.search,q='ChrisPaul').items(50)])
df['likes'] = np.array([tweet.favorite_count for tweet in tweepy.Cursor(api.search,q='ChrisPaul').items(50)])
df['date']=np.array([tweet.created_at for tweet in tweepy.Cursor(api.search,q='ChrisPaul').items(50)])
df["retweets"] = np.array([tweet.retweet_count for tweet in tweepy.Cursor(api.search,q='ChrisPaul').items(50)])
df
# Out:
#                Name                   id  likes                date  retweets
# 0    jucebabedagrea  1103134219621093377      0 2019-03-06 03:24:27         0
# 1    AggyCompugates  1103129059633127424      0 2019-03-06 03:03:57         0
# 2        _ChrisPaul  1103113679514599424      0 2019-03-06 02:02:50         0
# 3   sexytothecore69  1103092310492020736      0 2019-03-06 00:37:55         0
# 4        _ChrisPaul  1103071998769532929      0 2019-03-05 23:17:13         0
# 5        _ChrisPaul  1103051770954203137      0 2019-03-05 21:56:50      1217
# 6   ChrisPaul_Smith  1102966968926253058      0 2019-03-05 16:19:52    306554
# 7        _ChrisPaul  1102954702847856643      0 2019-03-05 15:31:07       284
# 8     its_chrispaul  1102867481444696064      0 2019-03-05 09:44:32      6387
# 9     its_chrispaul  1102834508074795008      0 2019-03-05 07:33:31       311
# 10    its_chrispaul  1102834252415143936      0 2019-03-05 07:32:30     10370
# ...

# %%
df.to_csv('ChrisPaul_Hashtag.csv')

# %%
df = pd.DataFrame(data=[tweet.user.screen_name for tweet in tweepy.Cursor(api.search,q='Harden').items(50)], columns=['Name']) 
df['id'] = np.array([tweet.id for tweet in tweepy.Cursor(api.search,q='Harden').items(50)])
df['likes'] = np.array([tweet.favorite_count for tweet in tweepy.Cursor(api.search,q='Harden').items(50)])
df['date']=np.array([tweet.created_at for tweet in tweepy.Cursor(api.search,q='Harden').items(50)])
df["retweets"] = np.array([tweet.retweet_count for tweet in tweepy.Cursor(api.search,q='Harden').items(50)])
df
# Out:
#                Name                   id  likes                date  retweets
# 0            MLC22_  1103140179638919168      0 2019-03-06 03:48:08         0
# 1    RossTrivisonno  1103140157652373504      0 2019-03-06 03:48:03        53
# 2            svgb23  1103140154443735045      0 2019-03-06 03:48:02        97
# 3       RafiRubiano  1103140148408184832      0 2019-03-06 03:48:01         0
# 4        BirdiWorld  1103140145929375744      0 2019-03-06 03:48:00       183
# 5         ShahSilas  1103140145686032384      0 2019-03-06 03:48:00         0
# 6         Chibettor  1103140144167686144      0 2019-03-06 03:48:00         0
# 7         paco_afan  1103140132717252608      0 2019-03-06 03:47:57         5
# 8         hass10009  1103140116917297157      0 2019-03-06 03:47:53        62
# 9          soybomb7  1103140110332321792      0 2019-03-06 03:47:52         0
# 10        _Thirst22  1103140108704903169      0 2019-03-06 03:47:51         0
# ...

# %%
df.to_csv('Harden_Hashtag.csv')

# %%
tweets = api.user_timeline('Lakers',count=100)
jt = api.get_user('Lakers')
for tweet in tweets:
    df = pd.DataFrame(data=[tweet.user.screen_name for tweet in tweets], columns=['Name'])
    df['id'] = np.array([jt.id for tweet in tweets])
    df['likes'] = np.array([tweet.favorite_count for tweet in tweets])
    df['date']=np.array([tweet.created_at for tweet in tweets])
    df['posts']= np.array([tweet.text for tweet in tweets])
    df["retweets"] = np.array([tweet.retweet_count for tweet in tweets])
    
df
# Out:
#       Name        id  likes                date  \
# 0   Lakers  20346956      0 2019-03-06 01:09:59
# 1   Lakers  20346956      0 2019-03-05 23:40:51
# 2   Lakers  20346956    471 2019-03-05 20:48:49
# 3   Lakers  20346956      0 2019-03-05 19:58:11
# 4   Lakers  20346956    486 2019-03-05 07:23:32
# 5   Lakers  20346956    625 2019-03-05 07:15:36
# 6   Lakers  20346956   1241 2019-03-05 07:13:44
# 7   Lakers  20346956      0 2019-03-05 06:49:37
# 8   Lakers  20346956    444 2019-03-05 06:46:31
# 9   Lakers  20346956   2024 2019-03-05 05:58:40
# 10  Lakers  20346956   2293 2019-03-05 05:52:10
# 11  Lakers  20346956   1635 2019-03-05 05:37:25
# 12  Lakers  20346956    985 2019-03-05 05:35:52
# 13  Lakers  20346956    494 2019-03-05 05:33:37
# 14  Lakers  20346956    431 2019-03-05 05:26:33
# 15  Lakers  20346956    568 2019-03-05 05:24:18
# 16  Lakers  20346956    648 2019-03-05 05:22:00
# 17  Lakers  20346956    424 2019-03-05 05:18:33
# ...

# %%
df.to_csv('Lakers_Twitter_Account.csv')

# %%
df = pd.DataFrame(data=[tweet.user.screen_name for tweet in tweepy.Cursor(api.search,q='LeBron').items(50)], columns=['Name']) 
df['id'] = np.array([tweet.id for tweet in tweepy.Cursor(api.search,q='LeBron').items(50)])
df['likes'] = np.array([tweet.favorite_count for tweet in tweepy.Cursor(api.search,q='LeBron').items(50)])
df['date']=np.array([tweet.created_at for tweet in tweepy.Cursor(api.search,q='LeBron').items(50)])
df["retweets"] = np.array([tweet.retweet_count for tweet in tweepy.Cursor(api.search,q='LeBron').items(50)])
df
# Out:
#                Name                   id  likes                date  retweets
# 0       GreenFiends  1103140209066196993      0 2019-03-06 03:48:15         1
# 1   XRobsPunchinBag  1103140207514267648      0 2019-03-06 03:48:15        56
# 2      Yallarechamp  1103140205853319168      0 2019-03-06 03:48:15         0
# 3    the_zachjordan  1103140203202523137      0 2019-03-06 03:48:14        34
# 4         elarrea10  1103140201847816194      0 2019-03-06 03:48:14         0
# 5       TheRealPG13  1103140194528776193      0 2019-03-06 03:48:12         7
# 6             tng35  1103140192268046336      0 2019-03-06 03:48:11         0
# 7       KJ_GO_CRAZY  1103140189264859137      0 2019-03-06 03:48:11       247
# 8        matty_gee8  1103140189122134016      0 2019-03-06 03:48:11       677
# 9         4hill2018  1103140188761448449      0 2019-03-06 03:48:11         0
# 10    VersaceWizard  1103140187230605313      0 2019-03-06 03:48:10     35271
# ...

# %%
df.to_csv('LeBron_Hashtag.csv')

# %%
df = pd.DataFrame(data=[tweet.user.screen_name for tweet in tweepy.Cursor(api.search,q='Rajon').items(50)], columns=['Name']) 
df['id'] = np.array([tweet.id for tweet in tweepy.Cursor(api.search,q='Rajon').items(50)])
df['likes'] = np.array([tweet.favorite_count for tweet in tweepy.Cursor(api.search,q='Rajon').items(50)])
df['date']=np.array([tweet.created_at for tweet in tweepy.Cursor(api.search,q='Rajon').items(50)])
df["retweets"] = np.array([tweet.retweet_count for tweet in tweepy.Cursor(api.search,q='Rajon').items(50)])
df
# Out:
#                Name                   id  likes                date  retweets
# 0    Bueno_No_Bueno  1103140133069561858      0 2019-03-06 03:47:57       158
# 1    JustinSobieski  1103140089390157824      0 2019-03-06 03:47:47       950
# 2      _BigDreams10  1103138813545775107      0 2019-03-06 03:42:43       950
# 3       Eddiecondee  1103137620543066112      0 2019-03-06 03:37:58       950
# 4         YamBSweet  1103137517380009984      0 2019-03-06 03:37:34       950
# 5        ommiobryce  1103136313748840449      0 2019-03-06 03:32:47        22
# 6          Fiandach  1103136025768050688      0 2019-03-06 03:31:38       950
# 7   SportsNewsToda4  1103134119867768832      0 2019-03-06 03:24:04         0
# 8       SPOOKdBOXER  1103134072250032134      0 2019-03-06 03:23:52       314
# 9       mas_jarrett  1103134016688062465      0 2019-03-06 03:23:39       950
# 10  blissfulclaudia  1103133835204542464      0 2019-03-06 03:22:56       950
# ...

# %%
df.to_csv('Rajon_Hashtag.csv')
