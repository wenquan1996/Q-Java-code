# %%
import pandas as pd
import http.client, urllib.request, urllib.parse, urllib.error, base64
import json

headers = {
    # Request headers
    'Ocp-Apim-Subscription-Key': 'e2d8e8a9e8fa47edbc1116ba50656057',
}

params = urllib.parse.urlencode({
})

try:
    conn = http.client.HTTPSConnection('api.fantasydata.net')
    conn.request("GET", "/v3/nba/stats/JSON/PlayerSeasonStatsByTeam/2019/HOU?%s" % params, None, headers)
    response = conn.getresponse()
    data = response.read()
    print(data)
    conn.close()
except Exception as e:
    print("[Errno {0}] {1}".format(e.errno, e.strerror))
# Out:
# b'[{"StatID":576288,"TeamID":22,"PlayerID":20000439,"SeasonType":1,"Season":2019,"Name":"Nene Hilario","Team":"HOU","Position":"C","Started":2,"GlobalTeamID":20000022,"Updated":"2019-03-05T18:19:44","Games":32,"FantasyPoints":348.4,"Minutes":475,"Seconds":25,"FieldGoalsMade":53.0,"FieldGoalsAttempted":96.9,"FieldGoalsPercentage":61.6,"EffectiveFieldGoalsPercentage":61.6,"TwoPointersMade":53.0,"TwoPointersAttempted":94.7,"TwoPointersPercentage":63.1,"ThreePointersMade":0.0,"ThreePointersAttempted":2.3,"ThreePointersPercentage":0.0,"FreeThrowsMade":30.4,"FreeThrowsAttempted":42.8,"FreeThrowsPercentage":80.1,"OffensiveRebounds":28.2,"DefensiveRebounds":76.6,"Rebounds":104.8,"OffensiveReboundsPercentage":7.2,"DefensiveReboundsPercentage":21.1,"TotalReboundsPercentage":14.0,"Assists":21.4,"Steals":16.9,"BlockedShots":14.7,"Turnovers":9.0,"PersonalFouls":76.6,"Points":136.4,"TrueShootingAttempts":115.8,"TrueShootingPercentage":66.5,"PlayerEfficiencyRating":15.8,"AssistsPercentage":7.3,"Ste
# ...

# %%
data
# Out:
# b'[{"StatID":576288,"TeamID":22,"PlayerID":20000439,"SeasonType":1,"Season":2019,"Name":"Nene Hilario","Team":"HOU","Position":"C","Started":2,"GlobalTeamID":20000022,"Updated":"2019-03-05T18:19:44","Games":32,"FantasyPoints":348.4,"Minutes":475,"Seconds":25,"FieldGoalsMade":53.0,"FieldGoalsAttempted":96.9,"FieldGoalsPercentage":61.6,"EffectiveFieldGoalsPercentage":61.6,"TwoPointersMade":53.0,"TwoPointersAttempted":94.7,"TwoPointersPercentage":63.1,"ThreePointersMade":0.0,"ThreePointersAttempted":2.3,"ThreePointersPercentage":0.0,"FreeThrowsMade":30.4,"FreeThrowsAttempted":42.8,"FreeThrowsPercentage":80.1,"OffensiveRebounds":28.2,"DefensiveRebounds":76.6,"Rebounds":104.8,"OffensiveReboundsPercentage":7.2,"DefensiveReboundsPercentage":21.1,"TotalReboundsPercentage":14.0,"Assists":21.4,"Steals":16.9,"BlockedShots":14.7,"Turnovers":9.0,"PersonalFouls":76.6,"Points":136.4,"TrueShootingAttempts":115.8,"TrueShootingPercentage":66.5,"PlayerEfficiencyRating":15.8,"AssistsPercentage":7.3,"Ste
# ...

# %%
a = json.loads(data)

# %%
a_df = pd.DataFrame(a)

# %%
a_df
# Out:
#     Assists  AssistsPercentage  BlockedShots  BlocksPercentage  \
# 0      21.4                7.3          14.7               3.0
# 1     119.5               11.6          23.7               1.2
# 2       0.0                0.0           0.0               0.0
# 3     504.9               44.4          50.7               2.0
# 4      76.6                7.9          93.5               4.9
# 5     110.4               13.4          23.7               1.7
# 6     374.2               44.4          12.4               0.8
# 7     158.9               14.1          23.7               1.2
# 8      20.3                6.1          21.4               3.2
# 9      41.7                5.1          25.9               1.8
# 10     86.8                5.4          32.7               1.3
# 11      7.9               11.3           0.0               0.0
# 12      0.0                0.0           0.0               0.0
# 13     29.3                6.9          11.3               1.6
# ...

# %%
a_df.to_csv("HoustonRockets_player_stats.csv")

# %%
headers = {
    # Request headers
    'Ocp-Apim-Subscription-Key': 'e2d8e8a9e8fa47edbc1116ba50656057',
}

params = urllib.parse.urlencode({
})

try:
    conn = http.client.HTTPSConnection('api.fantasydata.net')
    conn.request("GET", "/v3/nba/stats/JSON/PlayerSeasonStatsByTeam/2019/GS?%s" % params, None, headers)
    response = conn.getresponse()
    data = response.read()
    print(data)
    conn.close()
except Exception as e:
    print("[Errno {0}] {1}".format(e.errno, e.strerror))
# Out:
# b'[{"StatID":575663,"TeamID":26,"PlayerID":20000482,"SeasonType":1,"Season":2019,"Name":"Draymond Green","Team":"GS","Position":"PF","Started":48,"GlobalTeamID":20000026,"Updated":"2019-03-05T18:19:44","Games":48,"FantasyPoints":1578.7,"Minutes":1685,"Seconds":24,"FieldGoalsMade":148.8,"FieldGoalsAttempted":341.5,"FieldGoalsPercentage":49.1,"EffectiveFieldGoalsPercentage":54.7,"TwoPointersMade":115.0,"TwoPointersAttempted":209.6,"TwoPointersPercentage":61.8,"ThreePointersMade":33.8,"ThreePointersAttempted":131.9,"ThreePointersPercentage":28.9,"FreeThrowsMade":54.1,"FreeThrowsAttempted":75.5,"FreeThrowsPercentage":80.7,"OffensiveRebounds":49.6,"DefensiveRebounds":349.4,"Rebounds":399.0,"OffensiveReboundsPercentage":3.7,"DefensiveReboundsPercentage":24.1,"TotalReboundsPercentage":14.3,"Assists":387.7,"Steals":81.1,"BlockedShots":54.1,"Turnovers":137.5,"PersonalFouls":174.7,"Points":385.4,"TrueShootingAttempts":374.7,"TrueShootingPercentage":57.9,"PlayerEfficiencyRating":17.2,"AssistsPe
# ...

# %%
a = json.loads(data)
a_df = pd.DataFrame(a)
a_df.to_csv("Golden State Warriors_player_stats.csv")

# %%
headers = {
    # Request headers
    'Ocp-Apim-Subscription-Key': 'e2d8e8a9e8fa47edbc1116ba50656057',
}

params = urllib.parse.urlencode({
})

try:
    conn = http.client.HTTPSConnection('api.fantasydata.net')
    conn.request("GET", "/v3/nba/stats/JSON/PlayerSeasonStatsByTeam/2019/LAL?%s" % params, None, headers)
    response = conn.getresponse()
    data = response.read()
    print(data)
    conn.close()
except Exception as e:
    print("[Errno {0}] {1}".format(e.errno, e.strerror))
# Out:
# b'[{"StatID":576323,"TeamID":27,"PlayerID":20000528,"SeasonType":1,"Season":2019,"Name":"Tyson Chandler","Team":"LAL","Position":"C","Started":6,"GlobalTeamID":20000027,"Updated":"2019-03-05T18:19:44","Games":53,"FantasyPoints":705.4,"Minutes":953,"Seconds":30,"FieldGoalsMade":66.5,"FieldGoalsAttempted":109.3,"FieldGoalsPercentage":68.5,"EffectiveFieldGoalsPercentage":68.5,"TwoPointersMade":66.5,"TwoPointersAttempted":108.2,"TwoPointersPercentage":69.3,"ThreePointersMade":0.0,"ThreePointersAttempted":1.1,"ThreePointersPercentage":0.0,"FreeThrowsMade":55.2,"FreeThrowsAttempted":93.5,"FreeThrowsPercentage":66.5,"OffensiveRebounds":102.6,"DefensiveRebounds":232.2,"Rebounds":334.7,"OffensiveReboundsPercentage":12.9,"DefensiveReboundsPercentage":27.7,"TotalReboundsPercentage":20.5,"Assists":41.7,"Steals":23.7,"BlockedShots":24.8,"Turnovers":44.0,"PersonalFouls":121.7,"Points":188.2,"TrueShootingAttempts":150.5,"TrueShootingPercentage":70.4,"PlayerEfficiencyRating":14.8,"AssistsPercentage"
# ...

# %%
a = json.loads(data)
a_df = pd.DataFrame(a)
a_df.to_csv("Los Angeles Lakers_player_stats.csv")

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df1 = pd.read_csv("Los Angeles Lakers_player_stats.csv")
left = df1
df2 = pd.read_csv("Golden State Warriors_player_stats.csv")
right = df2
df3 = pd.merge(left,right,how = 'outer')

# %%
df3
# Out:
#     Unnamed: 0  Assists  AssistsPercentage  BlockedShots  BlocksPercentage  \
# 0            0     41.7                6.0          24.8               2.3
# 1            1    254.7               39.9           4.5               0.4
# 2            2    415.9               41.6          32.7               1.6
# 3            3     74.4                8.6          36.1               2.6
# 4            4    135.2               20.1           6.8               0.6
# 5            5      0.0                0.0           0.0               0.0
# 6            6     78.9                7.1          11.3               0.6
# 7            7     42.8                5.4         121.7               8.1
# 8            8    138.6               11.2          12.4               0.6
# 9            9     28.2               16.5          11.3               3.2
# 10          10    173.6               14.5          34.9               1.6
# ...

# %%
left = df3
df4 = pd.read_csv("HoustonRockets_player_stats.csv")
right = df4
df5 = pd.merge(left,right,how = 'outer')
df5
# Out:
#     Unnamed: 0  Assists  AssistsPercentage  BlockedShots  BlocksPercentage  \
# 0            0     41.7                6.0          24.8               2.3
# 1            1    254.7               39.9           4.5               0.4
# 2            2    415.9               41.6          32.7               1.6
# 3            3     74.4                8.6          36.1               2.6
# 4            4    135.2               20.1           6.8               0.6
# 5            5      0.0                0.0           0.0               0.0
# 6            6     78.9                7.1          11.3               0.6
# 7            7     42.8                5.4         121.7               8.1
# 8            8    138.6               11.2          12.4               0.6
# 9            9     28.2               16.5          11.3               3.2
# 10          10    173.6               14.5          34.9               1.6
# ...

# %%
df5.to_csv("PlayerStatsByTeam.csv")
