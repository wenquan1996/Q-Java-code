# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd

# %%
df1 = pd.read_csv("HoustonRockets_Twitter_Account.csv")
left = df1
df2 = pd.read_csv("Lakers_Twitter_Account.csv")
right = df2
df3 = pd.merge(left,right,how = 'outer')

# %%
left = df3
df4 = pd.read_csv("Warriors_Twitter_Account.csv")
right = df4
df5 = pd.merge(left,right,how = 'outer')
df5
# Out:
#      Unnamed: 0            Name        id  likes                 date  \
# 0             0  HoustonRockets  19077044    921  2019-03-05 02:14:28
# 1             1  HoustonRockets  19077044     65  2019-03-04 23:00:00
# 2             2  HoustonRockets  19077044   1670  2019-03-04 21:12:13
# 3             3  HoustonRockets  19077044     52  2019-03-04 21:00:00
# 4             4  HoustonRockets  19077044    938  2019-03-04 20:00:01
# 5             5  HoustonRockets  19077044   1003  2019-03-04 19:08:32
# 6             6  HoustonRockets  19077044    184  2019-03-04 19:00:00
# 7             7  HoustonRockets  19077044    484  2019-03-04 18:30:12
# 8             8  HoustonRockets  19077044     71  2019-03-04 18:00:00
# 9             9  HoustonRockets  19077044    477  2019-03-04 16:00:00
# 10           10  HoustonRockets  19077044    393  2019-03-04 15:30:00
# 11           11  HoustonRockets  19077044    511  2019-03-04 15:00:00
# ...

# %%
df5.to_csv('NBA_Team_Accout_Twitter.csv')
