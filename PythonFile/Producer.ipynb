# %%
import json
import oauth2 as oauth
import twitter
import numpy as np
import pandas as pd
import tweepy

# %%
consumer_key = 'nRO8b2R7tnipKtrFTJVRUru7V'  
consumer_secret = 'bK2v3PVVZGktAT2BbviC96Tz9vzjq0ZDj2WLKZ1pmm5aGgu4eW'  
access_token = '1098973181468205057-xXfZG8xbtYbXjE6T2s0Ok5J0bKRpsN'  
access_token_secret = 'W7muOM4ABrbSH59nHLH43YMeRl3GZCfN1v8FOh1p8tPHh' 
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)  
auth.set_access_token(access_token, access_token_secret)  
  
api = tweepy.API(auth)

# %%
tweets = api.user_timeline('JHarden13',count=100)
jt = api.get_user('JHarden13')
for tweet in tweets:
    df1 = pd.DataFrame(data=[tweet.user.screen_name for tweet in tweets], columns=['User_Name'])
    df1['id'] = np.array([jt.id for tweet in tweets])
    df1['likes'] = np.array([tweet.favorite_count for tweet in tweets])
    df1['date']=np.array([tweet.created_at for tweet in tweets])
    df1['posts']= np.array([tweet.text for tweet in tweets])
    df1["retweets"] = np.array([tweet.retweet_count for tweet in tweets])
    
df1
# Out:
#     User_Name        id   likes                date  \
# 0   JHarden13  50811932   10357 2019-03-06 16:51:24
# 1   JHarden13  50811932    5237 2019-03-04 05:05:59
# 2   JHarden13  50811932   25091 2019-02-24 05:39:43
# 3   JHarden13  50811932    3761 2019-02-17 16:46:03
# 4   JHarden13  50811932    9900 2019-02-14 17:50:13
# 5   JHarden13  50811932    1871 2019-02-13 21:56:18
# 6   JHarden13  50811932    5024 2019-02-13 00:13:29
# 7   JHarden13  50811932  105924 2019-02-12 23:21:13
# 8   JHarden13  50811932   37914 2019-02-10 20:27:24
# 9   JHarden13  50811932    8575 2019-02-10 18:35:14
# 10  JHarden13  50811932    8143 2019-02-08 23:46:00
# 11  JHarden13  50811932     506 2019-02-07 21:19:04
# 12  JHarden13  50811932   20425 2019-02-06 01:03:18
# 13  JHarden13  50811932    6695 2019-01-31 18:19:29
# 14  JHarden13  50811932     840 2019-01-28 23:01:36
# 15  JHarden13  50811932   11382 2019-01-28 20:50:05
# 16  JHarden13  50811932   42478 2019-01-25 03:01:32
# ...

# %%
tweets = api.user_timeline('CP3',count=100)
jt = api.get_user('CP3')
for tweet in tweets:
    df2 = pd.DataFrame(data=[tweet.user.screen_name for tweet in tweets], columns=['User_Name'])
    df2['id'] = np.array([jt.id for tweet in tweets])
    df2['likes'] = np.array([tweet.favorite_count for tweet in tweets])
    df2['date']=np.array([tweet.created_at for tweet in tweets])
    df2['posts']= np.array([tweet.text for tweet in tweets])
    df2["retweets"] = np.array([tweet.retweet_count for tweet in tweets])
    
df2
# Out:
#    User_Name        id  likes                date  \
# 0        CP3  53853197      0 2019-03-06 22:34:15
# 1        CP3  53853197   1612 2019-03-06 20:39:45
# 2        CP3  53853197    948 2019-03-04 20:05:53
# 3        CP3  53853197      0 2019-03-04 04:34:08
# 4        CP3  53853197    754 2019-03-01 23:00:40
# 5        CP3  53853197  12818 2019-03-01 22:07:39
# 6        CP3  53853197    375 2019-03-01 20:28:21
# 7        CP3  53853197  29390 2019-03-01 04:53:13
# 8        CP3  53853197  29917 2019-02-28 03:29:23
# 9        CP3  53853197    208 2019-02-27 16:50:07
# 10       CP3  53853197    831 2019-02-24 23:55:54
# 11       CP3  53853197      0 2019-02-21 04:38:41
# 12       CP3  53853197    413 2019-02-21 02:05:10
# 13       CP3  53853197      0 2019-02-20 22:24:12
# 14       CP3  53853197      0 2019-02-20 20:31:34
# 15       CP3  53853197    897 2019-02-16 20:07:44
# 16       CP3  53853197   4861 2019-02-15 18:38:42
# 17       CP3  53853197   3754 2019-02-10 22:08:33
# ...

# %%
tweets = api.user_timeline('KDTrey5',count=100)
jt = api.get_user('KDTrey5')
for tweet in tweets:
    df3 = pd.DataFrame(data=[tweet.user.screen_name for tweet in tweets], columns=['User_Name'])
    df3['id'] = np.array([jt.id for tweet in tweets])
    df3['likes'] = np.array([tweet.favorite_count for tweet in tweets])
    df3['date']=np.array([tweet.created_at for tweet in tweets])
    df3['posts']= np.array([tweet.text for tweet in tweets])
    df3["retweets"] = np.array([tweet.retweet_count for tweet in tweets])
    
df3
# Out:
#    User_Name        id  likes                date  \
# 0    KDTrey5  35936474      0 2019-03-01 21:24:29
# 1    KDTrey5  35936474  31708 2019-03-01 18:54:37
# 2    KDTrey5  35936474      0 2019-02-28 21:58:05
# 3    KDTrey5  35936474      0 2019-02-24 19:56:22
# 4    KDTrey5  35936474      0 2019-02-19 21:41:31
# 5    KDTrey5  35936474      0 2019-02-17 17:21:28
# 6    KDTrey5  35936474      0 2019-02-15 16:48:47
# 7    KDTrey5  35936474      0 2019-02-14 19:51:42
# 8    KDTrey5  35936474      0 2019-02-12 18:14:16
# 9    KDTrey5  35936474      0 2019-02-11 17:46:48
# 10   KDTrey5  35936474      0 2019-02-11 17:23:51
# 11   KDTrey5  35936474      0 2019-02-09 15:24:04
# 12   KDTrey5  35936474      0 2019-01-24 15:50:36
# 13   KDTrey5  35936474  11575 2019-01-24 04:07:38
# 14   KDTrey5  35936474      0 2018-12-25 16:45:51
# 15   KDTrey5  35936474      0 2018-12-18 19:57:22
# 16   KDTrey5  35936474      0 2018-12-17 23:39:24
# 17   KDTrey5  35936474      0 2018-12-04 20:59:59
# ...

# %%
tweets = api.user_timeline('StephenCurry30',count=100)
jt = api.get_user('StephenCurry30')
for tweet in tweets:
    df4 = pd.DataFrame(data=[tweet.user.screen_name for tweet in tweets], columns=['User_Name'])
    df4['id'] = np.array([jt.id for tweet in tweets])
    df4['likes'] = np.array([tweet.favorite_count for tweet in tweets])
    df4['date']=np.array([tweet.created_at for tweet in tweets])
    df4['posts']= np.array([tweet.text for tweet in tweets])
    df4["retweets"] = np.array([tweet.retweet_count for tweet in tweets])
    
df4
# Out:
#          User_Name        id   likes                date  \
# 0   StephenCurry30  42562446     654 2019-03-03 08:38:40
# 1   StephenCurry30  42562446   10186 2019-03-02 01:54:55
# 2   StephenCurry30  42562446   15156 2019-02-28 00:15:33
# 3   StephenCurry30  42562446   17753 2019-02-25 23:42:40
# 4   StephenCurry30  42562446   19111 2019-02-24 01:16:12
# 5   StephenCurry30  42562446   20980 2019-02-22 21:33:12
# 6   StephenCurry30  42562446   19580 2019-02-22 03:16:57
# 7   StephenCurry30  42562446   62293 2019-02-19 07:18:00
# 8   StephenCurry30  42562446    9508 2019-02-17 17:25:28
# 9   StephenCurry30  42562446       0 2019-02-16 21:55:06
# 10  StephenCurry30  42562446    8815 2019-02-15 02:42:56
# 11  StephenCurry30  42562446   13812 2019-02-14 03:17:20
# 12  StephenCurry30  42562446   15727 2019-02-13 03:12:30
# 13  StephenCurry30  42562446   26250 2019-02-12 21:24:18
# 14  StephenCurry30  42562446   21957 2019-02-11 06:20:19
# ...

# %%
tweets = api.user_timeline('KingJames',count=100)
jt = api.get_user('KingJames')
for tweet in tweets:
    df5 = pd.DataFrame(data=[tweet.user.screen_name for tweet in tweets], columns=['User_Name'])
    df5['id'] = np.array([jt.id for tweet in tweets])
    df5['likes'] = np.array([tweet.favorite_count for tweet in tweets])
    df5['date']=np.array([tweet.created_at for tweet in tweets])
    df5['posts']= np.array([tweet.text for tweet in tweets])
    df5["retweets"] = np.array([tweet.retweet_count for tweet in tweets])
    
df5
# Out:
#     User_Name        id   likes                date  \
# 0   KingJames  23083404   35990 2019-03-07 01:53:05
# 1   KingJames  23083404   35961 2019-03-04 08:24:07
# 2   KingJames  23083404   39200 2019-03-01 22:53:53
# 3   KingJames  23083404    4426 2019-03-01 17:46:53
# 4   KingJames  23083404   10906 2019-03-01 17:44:01
# 5   KingJames  23083404       0 2019-02-28 19:46:40
# 6   KingJames  23083404   49480 2019-02-28 08:05:26
# 7   KingJames  23083404       0 2019-02-28 01:36:55
# 8   KingJames  23083404       0 2019-02-28 01:36:51
# 9   KingJames  23083404       0 2019-02-28 01:36:49
# 10  KingJames  23083404       0 2019-02-28 01:36:47
# 11  KingJames  23083404   12986 2019-02-27 19:35:14
# 12  KingJames  23083404   42058 2019-02-24 18:40:47
# 13  KingJames  23083404   28320 2019-02-23 22:09:57
# 14  KingJames  23083404   59736 2019-02-23 01:19:55
# 15  KingJames  23083404  138478 2019-02-22 19:41:46
# 16  KingJames  23083404       0 2019-02-21 19:47:24
# ...

# %%
tweets = api.user_timeline('RajonRondo',count=100)
jt = api.get_user('RajonRondo')
for tweet in tweets:
    df6 = pd.DataFrame(data=[tweet.user.screen_name for tweet in tweets], columns=['User_Name'])
    df6['id'] = np.array([jt.id for tweet in tweets])
    df6['likes'] = np.array([tweet.favorite_count for tweet in tweets])
    df6['date']=np.array([tweet.created_at for tweet in tweets])
    df6['posts']= np.array([tweet.text for tweet in tweets])
    df6["retweets"] = np.array([tweet.retweet_count for tweet in tweets])
    
df6
# Out:
#      User_Name         id  likes                date  \
# 0   RajonRondo  150846769    806 2017-08-23 19:39:25
# 1   RajonRondo  150846769    268 2017-08-04 17:04:50
# 2   RajonRondo  150846769    688 2017-08-02 19:33:00
# 3   RajonRondo  150846769      0 2017-06-16 21:25:37
# 4   RajonRondo  150846769      0 2017-06-08 22:44:50
# 5   RajonRondo  150846769    132 2017-03-16 23:52:07
# 6   RajonRondo  150846769    159 2017-03-15 00:50:45
# 7   RajonRondo  150846769      0 2017-03-09 18:38:33
# 8   RajonRondo  150846769    264 2017-02-06 20:23:08
# 9   RajonRondo  150846769   1572 2017-01-16 18:12:38
# 10  RajonRondo  150846769   2253 2017-01-11 18:07:11
# 11  RajonRondo  150846769    359 2016-12-20 21:32:57
# 12  RajonRondo  150846769    459 2016-11-29 20:43:51
# 13  RajonRondo  150846769      0 2016-11-26 00:01:16
# 14  RajonRondo  150846769      0 2016-11-04 00:47:57
# 15  RajonRondo  150846769   1568 2016-09-27 00:23:02
# 16  RajonRondo  150846769  11124 2016-09-24 02:53:37
# ...

# %%
left = df1
right = df2
df11 = pd.merge(left,right,how = 'outer')
df11
# Out:
#      User_Name        id   likes                date  \
# 0    JHarden13  50811932   10357 2019-03-06 16:51:24
# 1    JHarden13  50811932    5237 2019-03-04 05:05:59
# 2    JHarden13  50811932   25091 2019-02-24 05:39:43
# 3    JHarden13  50811932    3761 2019-02-17 16:46:03
# 4    JHarden13  50811932    9900 2019-02-14 17:50:13
# 5    JHarden13  50811932    1871 2019-02-13 21:56:18
# 6    JHarden13  50811932    5024 2019-02-13 00:13:29
# 7    JHarden13  50811932  105924 2019-02-12 23:21:13
# 8    JHarden13  50811932   37914 2019-02-10 20:27:24
# 9    JHarden13  50811932    8575 2019-02-10 18:35:14
# 10   JHarden13  50811932    8143 2019-02-08 23:46:00
# 11   JHarden13  50811932     506 2019-02-07 21:19:04
# 12   JHarden13  50811932   20425 2019-02-06 01:03:18
# 13   JHarden13  50811932    6695 2019-01-31 18:19:29
# 14   JHarden13  50811932     840 2019-01-28 23:01:36
# 15   JHarden13  50811932   11382 2019-01-28 20:50:05
# 16   JHarden13  50811932   42478 2019-01-25 03:01:32
# ...

# %%
left = df3
right = df4
df22 = pd.merge(left,right,how = 'outer')

# %%
left = df5
right = df6
df33 = pd.merge(left,right,how = 'outer')

# %%
left = df11
right = df22
df111 = pd.merge(left,right,how = 'outer')

# %%
left = df33
right = df111
dfff = pd.merge(left,right,how = 'outer')
dfff
# Out:
#           User_Name        id   likes                date  \
# 0         KingJames  23083404   35990 2019-03-07 01:53:05
# 1         KingJames  23083404   35961 2019-03-04 08:24:07
# 2         KingJames  23083404   39200 2019-03-01 22:53:53
# 3         KingJames  23083404    4426 2019-03-01 17:46:53
# 4         KingJames  23083404   10906 2019-03-01 17:44:01
# 5         KingJames  23083404       0 2019-02-28 19:46:40
# 6         KingJames  23083404   49480 2019-02-28 08:05:26
# 7         KingJames  23083404       0 2019-02-28 01:36:55
# 8         KingJames  23083404       0 2019-02-28 01:36:51
# 9         KingJames  23083404       0 2019-02-28 01:36:49
# 10        KingJames  23083404       0 2019-02-28 01:36:47
# 11        KingJames  23083404   12986 2019-02-27 19:35:14
# 12        KingJames  23083404   42058 2019-02-24 18:40:47
# 13        KingJames  23083404   28320 2019-02-23 22:09:57
# 14        KingJames  23083404   59736 2019-02-23 01:19:55
# ...

# %%
dfff.to_csv('Player_Producer.csv')
